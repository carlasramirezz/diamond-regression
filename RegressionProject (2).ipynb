# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/diamond_datarevised.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159034 entries, 0 to 159033
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   clarity            159034 non-null  int64
#  1   carat_weight       159034 non-null  float64
#  2   cut_quality        159000 non-null  float64
#  3   symmetry           159009 non-null  float64
#  4   polish             159019 non-null  float64
#  5   depth_percent      159034 non-null  float64
#  6   table_percent      159034 non-null  float64
#  7   meas_length        159034 non-null  float64
#  8   meas_width         159034 non-null  float64
#  9   meas_depth         159034 non-null  float64
#  10  total_sales_price  159034 non-null  int64
# dtypes: float64(9), int64(2)
# memory usage: 13.3 MB

# %%
df1 = df.dropna(axis=0)

# %% [markdown]
# Removing the null values in the entire dataset.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158987 entries, 0 to 159033
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   clarity            158987 non-null  int64
#  1   carat_weight       158987 non-null  float64
#  2   cut_quality        158987 non-null  float64
#  3   symmetry           158987 non-null  float64
#  4   polish             158987 non-null  float64
#  5   depth_percent      158987 non-null  float64
#  6   table_percent      158987 non-null  float64
#  7   meas_length        158987 non-null  float64
#  8   meas_width         158987 non-null  float64
#  9   meas_depth         158987 non-null  float64
#  10  total_sales_price  158987 non-null  int64
# dtypes: float64(9), int64(2)
# memory usage: 14.6 MB

# %%
df1.head(10)
# Out:
#    clarity  carat_weight  cut_quality  symmetry  polish  depth_percent  \
# 0       78          0.09          1.0       0.0     0.0           62.7
# 1       78          0.09          0.0       0.0     0.0           61.9
# 2       78          0.09          1.0       0.0     0.0           61.1
# 3       78          0.09          1.0       0.0     0.0           62.0
# 4       78          0.09          0.0       0.0     1.0           64.9
# 5       78          0.09          0.0       0.0     0.0           60.8
# 6       78          0.09          0.0       0.0     0.0           64.0
# 7       78          0.09          1.0       0.0     0.0           62.1
# 8       78          0.09          0.0       0.0     0.0           63.5
# 9       78          0.09          1.0       0.0     0.0           63.2
#
#    table_percent  meas_length  meas_width  meas_depth  total_sales_price
# 0           59.0         2.85        2.87        1.79                200
# ...

# %%
df1.tail(10)
# Out:
#         clarity  carat_weight  cut_quality  symmetry  polish  depth_percent  \
# 159024       67         18.13          1.0       1.0     1.0           61.6
# 159025      100         13.03          1.0       1.0     1.0           62.9
# 159026       78         10.66          1.0       1.0     1.0           59.4
# 159027       67         10.70          1.0       1.0     1.0           61.0
# 159028      100         10.66          1.0       1.0     1.0           61.4
# 159029       78         10.10          1.0       1.0     1.0           59.4
# 159030      100         12.52          1.0       1.0     1.0           62.1
# 159031      100         12.52          1.0       1.0     1.0           62.1
# 159032       67         10.65          1.0       1.0     1.0           61.3
# 159033       67         18.07          1.0       1.0     1.0           60.2
#
#         table_percent  meas_length  meas_width  meas_depth  total_sales_price
# ...

# %%
df1.shape
# Out:
# (158987, 11)

# %%
df1.dtypes
# Out:
# clarity                int64
# carat_weight         float64
# cut_quality          float64
# symmetry             float64
# polish               float64
# depth_percent        float64
# table_percent        float64
# meas_length          float64
# meas_width           float64
# meas_depth           float64
# total_sales_price      int64
# dtype: object

# %%
df1.describe(include='all')
# Out:
#              clarity   carat_weight    cut_quality       symmetry  \
# count  158987.000000  158987.000000  158987.000000  158987.000000
# mean       61.433337       0.624086       0.785152       0.748891
# std        20.691347       0.677121       0.410718       0.433652
# min        12.000000       0.080000       0.000000       0.000000
# 25%        45.000000       0.300000       1.000000       0.000000
# 50%        56.000000       0.400000       1.000000       1.000000
# 75%        78.000000       0.700000       1.000000       1.000000
# max       100.000000      18.430000       1.000000       1.000000
#
#               polish  depth_percent  table_percent    meas_length  \
# count  158987.000000  158987.000000  158987.000000  158987.000000
# mean        0.860121      60.721813      56.444468       5.091673
# std         0.346863       9.185105       9.215987       1.331064
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df1.describe(include=['number'])
# Out:
#              clarity   carat_weight    cut_quality       symmetry  \
# count  158987.000000  158987.000000  158987.000000  158987.000000
# mean       61.433337       0.624086       0.785152       0.748891
# std        20.691347       0.677121       0.410718       0.433652
# min        12.000000       0.080000       0.000000       0.000000
# 25%        45.000000       0.300000       1.000000       0.000000
# 50%        56.000000       0.400000       1.000000       1.000000
# 75%        78.000000       0.700000       1.000000       1.000000
# max       100.000000      18.430000       1.000000       1.000000
#
#               polish  depth_percent  table_percent    meas_length  \
# count  158987.000000  158987.000000  158987.000000  158987.000000
# mean        0.860121      60.721813      56.444468       5.091673
# std         0.346863       9.185105       9.215987       1.331064
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# We are dropping these columns becasue they contain missing variables.

# %%
df1.head(10)
# Out:
#    clarity  carat_weight  cut_quality  symmetry  polish  depth_percent  \
# 0       78          0.09          1.0       0.0     0.0           62.7
# 1       78          0.09          0.0       0.0     0.0           61.9
# 2       78          0.09          1.0       0.0     0.0           61.1
# 3       78          0.09          1.0       0.0     0.0           62.0
# 4       78          0.09          0.0       0.0     1.0           64.9
# 5       78          0.09          0.0       0.0     0.0           60.8
# 6       78          0.09          0.0       0.0     0.0           64.0
# 7       78          0.09          1.0       0.0     0.0           62.1
# 8       78          0.09          0.0       0.0     0.0           63.5
# 9       78          0.09          1.0       0.0     0.0           63.2
#
#    table_percent  meas_length  meas_width  meas_depth  total_sales_price
# 0           59.0         2.85        2.87        1.79                200
# ...

# %% [markdown]
# Our target variable is the sales price of the diamond.

# %%
df1.boxplot(figsize=(12,9))
# Out:
# <Axes: >

# %%
df1['carat_weight'].hist(bins=20)
# Out:
# <Axes: >

# %%
df1.boxplot('carat_weight', figsize = (9,25))
# Out:
# <Axes: >

# %%
df2 = df1[df1['carat_weight'] < 0.8] #treating the outliers

# %%
df2.shape # we excluded about 1600 rows
# Out:
# (125903, 11)

# %%
df2.boxplot('carat_weight', figsize = (9,15)) #new histogram without the outliers
# Out:
# <Axes: >

# %%
df2['depth_percent'].hist(bins=99)
# Out:
# <Axes: >

# %%
df2.boxplot('depth_percent',figsize = (8,30))
# Out:
# <Axes: >

# %%
df2 = df2[df2['depth_percent'] < 70] #treating the outliers

# %%
df2 = df2[df2['depth_percent'] > 55]

# %%
df2.shape #we excluded about 8000 rows
# Out:
# (122981, 11)

# %%
df2.boxplot('depth_percent',figsize = (8,20))
# Out:
# <Axes: >

# %%
df2['table_percent'].hist(bins=20)
# Out:
# <Axes: >

# %%
df2.boxplot('table_percent',figsize=(9,10))
# Out:
# <Axes: >

# %%
df2 = df2[df2['table_percent'] < 70] #removing outliers

# %%
df2 = df2[df2['table_percent'] > 45]

# %%
df2.shape
# Out:
# (121394, 11)

# %%
df2.boxplot('table_percent',figsize=(9,10))
# Out:
# <Axes: >

# %%
df2['meas_length'].hist(bins=20)
# Out:
# <Axes: >

# %%
df2.boxplot('meas_length',figsize=(9,10))
# Out:
# <Axes: >

# %%
df2 = df2[df2['meas_length'] < 25]

# %%
df2 = df2[df2['meas_length'] > 0]

# %%
df2.shape
# Out:
# (120976, 11)

# %%
df2.boxplot('meas_length',figsize=(9,10))
# Out:
# <Axes: >

# %%
df2['meas_width'].hist(bins=10)
# Out:
# <Axes: >

# %%
df2.boxplot('meas_width',figsize=(9,10))
# Out:
# <Axes: >

# %%
df2 = df2[df2['meas_width'] < 14]

# %%
df2.boxplot('meas_width', figsize=(9,10))
# Out:
# <Axes: >

# %%
df2.shape
# Out:
# (120973, 11)

# %%
df2['meas_depth'].hist(bins=55)
# Out:
# <Axes: >

# %%
df2.boxplot('meas_depth', figsize=(9,30))
# Out:
# <Axes: >

# %%
df2 = df2[df2['meas_depth'] <8] # removing outliers

# %%
df2 = df2[df2['meas_depth'] >3] # removing outliers

# %%
df2.shape
# Out:
# (38023, 11)

# %%
df2.boxplot('meas_depth', figsize=(9,10))
# Out:
# <Axes: >

# %%
df2.boxplot('clarity', figsize=(9,10))
# Out:
# <Axes: >

# %%
df2.plot(kind='scatter',x='clarity',y='total_sales_price')
# Out:
# <Axes: xlabel='clarity', ylabel='total_sales_price'>

# %%
df2.plot(kind='scatter',x='meas_depth',y='total_sales_price')
# Out:
# <Axes: xlabel='meas_depth', ylabel='total_sales_price'>

# %%
df2.shape
# Out:
# (38023, 11)

# %%
df2.select_dtypes(include=np.number).corr()
# Out:
#                     clarity  carat_weight  cut_quality  symmetry    polish  \
# clarity            1.000000     -0.012581     0.063039  0.084420  0.133993
# carat_weight      -0.012581      1.000000     0.015142  0.027786 -0.004416
# cut_quality        0.063039      0.015142     1.000000  0.550661  0.283522
# symmetry           0.084420      0.027786     0.550661  1.000000  0.335546
# polish             0.133993     -0.004416     0.283522  0.335546  1.000000
# depth_percent      0.001302     -0.016403    -0.402854 -0.237702 -0.024014
# table_percent      0.029659     -0.017743    -0.028519 -0.010084 -0.034924
# meas_length       -0.009327      0.959967     0.157032  0.128833  0.015688
# meas_width        -0.006950      0.969045     0.139535  0.100386  0.011092
# meas_depth        -0.001228      0.934199    -0.015671  0.018175  0.008570
# total_sales_price  0.442926      0.585548     0.102391  0.083124  0.089356
#
# ...

# %%
plt.figure(figsize=(300, 300))

# %%
sns.heatmap (df2.corr(), cmap= "YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
X = df2[['carat_weight','depth_percent','table_percent','meas_width','meas_length','meas_depth']]

# %%
Y = df2[['total_sales_price']]

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(X,Y)
# Out:
# LinearRegression()

# %%
regr.predict(X)
# Out:
# array([[3618.52540918],
#        [ 945.54662488],
#        [2301.94093404],
#        ...,
#        [4375.15023627],
#        [4284.69304126],
#        [4028.64448667]])

# %%
df2['predicted_total_sales_price'] = regr.predict(X)

# %%
df2.head(10)
# Out:
#       clarity  carat_weight  cut_quality  symmetry  polish  depth_percent  \
# 560        12          0.70          0.0       0.0     1.0           61.8
# 845        56          0.30          1.0       1.0     1.0           62.2
# 1194       23          0.50          1.0       1.0     1.0           61.5
# 2474       34          0.45          1.0       1.0     1.0           61.3
# 2486       23          0.45          1.0       1.0     1.0           60.4
# 2644       23          0.46          0.0       0.0     0.0           61.6
# 3241       12          0.45          1.0       1.0     1.0           62.5
# 3625       23          0.51          1.0       1.0     1.0           62.5
# 3949       34          0.50          1.0       0.0     0.0           58.8
# 4496       23          0.50          0.0       0.0     1.0           64.4
#
#       table_percent  meas_length  meas_width  meas_depth  total_sales_price  \
# 560            58.0         5.62        5.68        3.49                390
# ...

# %%
regr.coef_.tolist()
# Out:
# [[-125.15125137358896,
#   68.10452130104295,
#   22.196946931205147,
#   1689.7738448661005,
#   452.7881274082291,
#   176.48821539271802]]

# %%
regr.intercept_
# Out:
# array([-14548.67963987])

# %%
regr.score(X,Y)
# Out:
# 0.35024551517977787

# %% [markdown]
# X-values of only the numeric variables

# %%
X = df2[['carat_weight','depth_percent','meas_width','meas_length','meas_depth']]

# %%
Y = df2[['total_sales_price']]

# %%
regr2 = linear_model.LinearRegression()

# %%
regr2.fit(X,Y)
# Out:
# LinearRegression()

# %%
regr2.predict(X)
# Out:
# array([[3632.65602343],
#        [ 885.66561251],
#        [2384.27172435],
#        ...,
#        [4359.72238791],
#        [4239.81246389],
#        [4015.64516911]])

# %%
regr2.score(X,Y)
# Out:
# 0.3491569824430736

# %%
X = df2[['clarity', 'carat_weight']]

# %%
Y = df2[['total_sales_price']]

# %%
regr3 = linear_model.LinearRegression()

# %%
regr3.fit(X,Y)
# Out:
# LinearRegression()

# %%
regr3.predict(X)
# Out:
# array([[2647.58592937],
#        [ 927.4915408 ],
#        [1546.43104357],
#        ...,
#        [4872.24480089],
#        [4738.01854316],
#        [4912.01310581]])

# %%
regr3.score(X,Y)
# Out:
# 0.5456624172827753

# %%
X = df2[['clarity', 'carat_weight', 'meas_length', 'meas_width']]

# %%
Y = df2[['total_sales_price']]

# %%
regr4 = linear_model.LinearRegression()

# %%
regr4.fit(X,Y)
# Out:
# LinearRegression()

# %%
regr4.predict(X)
# Out:
# array([[2639.14752023],
#        [ 769.53798176],
#        [1586.56931633],
#        ...,
#        [5051.65150716],
#        [4898.76922608],
#        [4933.01748672]])

# %%
regr4.score(X,Y)
# Out:
# 0.5498061927810283

# %% [markdown]
# After running four regressions, this has been the strongest one. X-values: clarity, carat weight, measure length and measure width. This was our best performing regression model. It explains 54.9%

# %%
df2.shape
# Out:
# (38023, 12)

# %%
df2['total_sales_price'].describe()
# Out:
# count    38023.000000
# mean      2782.731058
# std        984.471469
# min        390.000000
# 25%       2046.000000
# 50%       2752.000000
# 75%       3420.000000
# max       8280.000000
# Name: total_sales_price, dtype: float64

# %%
df2.describe(include='all')
# Out:
#             clarity  carat_weight   cut_quality      symmetry        polish  \
# count  38023.000000  38023.000000  38023.000000  38023.000000  38023.000000
# mean      59.236673      0.565864      0.751440      0.727454      0.866660
# std       20.227789      0.086724      0.432184      0.445275      0.339947
# min       12.000000      0.300000      0.000000      0.000000      0.000000
# 25%       45.000000      0.500000      1.000000      0.000000      1.000000
# 50%       56.000000      0.520000      1.000000      1.000000      1.000000
# 75%       78.000000      0.610000      1.000000      1.000000      1.000000
# max      100.000000      0.790000      1.000000      1.000000      1.000000
#
#        depth_percent  table_percent   meas_length    meas_width    meas_depth  \
# count   38023.000000   38023.000000  38023.000000  38023.000000  38023.000000
# mean       62.271488      57.730532      5.246445      5.282085      3.279318
# ...

# %% [markdown]
# Additional data for regression analysis above.
